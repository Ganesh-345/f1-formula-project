# %%
bronze_path ="abfss://bronze@stdevelopmentgani.dfs.core.windows.net/formula1fullloadlanding"
silver_path="abfss://silver@stdevelopmentgani.dfs.core.windows.net/formula1fullloadlanding"
gold_path="abfss://gold@stdevelopmentgani.dfs.core.windows.net/formula1fullloadlanding"
catlog_name='dev'
silver_schema ='silver'
gold_schema ='gold'
